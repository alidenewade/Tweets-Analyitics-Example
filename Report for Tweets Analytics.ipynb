# %% [markdown]
# # Twitter Data Analysis for 22seven:
# ### Insights and Recommendations
# #### by [Ali Denewade](https://www.datacamp.com/certificate/DS0025541624864)
#
#
# ![1_Htzal6ZqJnboGl4A-nQJFQ.png](attachment:1_Htzal6ZqJnboGl4A-nQJFQ.png)
#
# <u>**Executive Summary**</u>
#
# The Twitter data analysis for 22seven was conducted from 2012-01-01 until 2023-04-01. The top two most common tokens in the tweets were "app" (1948) and "money" (1127). The average tweet length was 7.69 characters. The sentiments for both "app" and "money" were mostly positive across time, with average compounds for polarity between 0.15 and 0.6. The "app" was frequently mentioned more than "money" across time. The top 5 users by reply, retweet, like, and quote counts were also identified.
#
# <u>**Tweets Length**</u>
#
# The average tweet length for the data analyzed was 7.69 characters.
#
# ![avg length.png](<attachment:avg length.png>)
#
#
# <u>**Sentiment Analysis**</u>
#
# The sentiments for both "app" and "money" were mostly positive across time. The average compounds for polarity were between 0.15 and 0.6.
#
# ![SentimentTotal.png](attachment:SentimentTotal.png)
#
# ![SentimentAvg.png](attachment:SentimentAvg.png)
#
# <u>**App vs. Money**</u>
#
# The "app" was frequently mentioned more than "money" across time.
#
# ![SentimentFreq.png](attachment:SentimentFreq.png)
#
#
# <u>**Top 5 Most Active Users**</u>
#
# The top 5 most active users across all engagement categories were identified. These users are [Hlubikaz](https://twitter.com/_Hlubikaz), [AndreBothmaTax](https://twitter.com/AndreBothmaTax), [SimonDingle](https://twitter.com/SimonDingle), [sindivanzyl](https://twitter.com/sindivanzyl), and [OldMutualSA](https://twitter.com/OldMutualSA).
#
# ![Influencers.png](attachment:Influencers.png)
#
# <u>**Conclusion**</u>
#
# Based on the Twitter data analysis conducted, it can be concluded that the "app" is a popular topic among Twitter users when it comes to discussing 22seven. The sentiment analysis conducted on the tweets shows that the sentiments for both "app" and "money" are mostly positive, which is a good indication of the brand. Furthermore, the top 5 users by interaction count can provide insights into the most engaged users and potential brand ambassadors.
#
# <u>**Recommendation**</u>
#
# Based on the analysis, it is recommended that 22seven should continue to focus on improving their app and user experience to maintain their popularity on Twitter. They should also consider engaging with the top 5 users by interaction count to strengthen their relationships and potentially expand their reach through these users.
